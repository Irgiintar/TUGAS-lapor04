# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = {
    'Tinggi': [ 170, 175, 180, 185, 190],
    'Berat': [  70, 75, 80, 85, 90]
}

# %%
df = pd.DataFrame(data)

# %%
data
# Out:
# {'Tinggi': [170, 175, 180, 185, 190], 'Berat': [70, 75, 80, 85, 90]}

# %%
x = df[['Tinggi']]
y = df['Berat']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['Tinggi'], df['Berat'])
plt.plot(x_train, model.predict(x_train), color = 'red')
plt.xlabel('Tinggi (cm)')
plt.ylabel('Berat (kg)')
plt.title(' Berat VS Tinggi')
plt.show()

# %%
# Membuat prediksi untuk tinggi dan berat badan
tinggi_anda = [[175]]  
berat_anda = model.predict(tinggi_anda)
print(f'Prediksi berat badan untuk tinggi {tinggi_anda[0][0]} cm: {berat_anda[0]} kg')
# Out:
# Prediksi berat badan untuk tinggi 175 cm: 75.0 kg
# D:\Andryan\Anaconda\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
